# %% [markdown]
# ## レース結果の前処理

# %%
from modules import preprocessing
from modules.constants import local_paths 
import os
import pandas as pd
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload

# %%
y=2020

# %%
results_p = preprocessing.process_results(save_file_name=f'results_{y}.csv')

# %%
path = os.path.join(local_paths.RAW_DIR, f"results_{y}.csv")
results = pd.read_csv(path, index_col=0, encoding='utf8', sep='\t')

# %%
for y in range(2020, 2024):
  results_path = os.path.join(local_paths.PREPROCESSED_DIR, f"results_{y}.csv")
  results_p = pd.read_csv(results_path, index_col=0, encoding='utf8', sep='\t')
  results_p = results_p.drop(columns=['owner_id'])
  results_p.to_csv(os.path.join(local_paths.PREPROCESSED_DIR, f"results_{y}.csv"), sep="\t")

# %%
results_p
# Out:
#             race_id    horse_id  jockey_id  trainer_id  rank  frame  number  \
# 27404  202301010101  2021100648       1095        1128   5.0      1       1
# 27405  202301010101  2021100159       1157        1186   6.0      2       2
# 27406  202301010101  2021100265       1197        1192   7.0      3       3
# 27403  202301010101  2021105553       5339        1160   4.0      4       4
# 27400  202301010101  2021101429       1170        1026   1.0      5       5
# ...             ...         ...        ...         ...   ...    ...     ...
# 33202  202310030812  2019102542       1208        1161   1.0      6       8
# 33207  202310030812  2020103754       1116        1104   6.0      7       9
# 33205  202310030812  2020100400       1193        1092   4.0      7      10
# 33203  202310030812  2020103663        732        1092   2.0      8      11
# 33206  202310030812  2017104623       1125        1170   5.0      8      12
#
# ...

# %%
results_22_path = os.path.join(local_paths.PREPROCESSED_DIR, "results_2021.csv")
results_22_p = pd.read_csv(results_22_path, index_col=0, encoding='utf8', sep='\t')
results_23_path = os.path.join(local_paths.PREPROCESSED_DIR, "results_2020.csv")
results_23_p = pd.read_csv(results_23_path, index_col=0, encoding='utf8', sep='\t')

# %%
results_22_p
# Out:
#             race_id    horse_id  jockey_id  trainer_id  owner_id  rank  frame  \
# 21851  202101010101  2018104780       1144        1136    414030  15.0      1
# 21842  202101010101  2018100570        666        1039    728008   6.0      1
# 21846  202101010101  2018101518       1173        1093    942006  10.0      2
# 21848  202101010101  2018101447       1091        1076    546800  12.0      2
# 21841  202101010101  2018101539       1015         417    163002   5.0      3
# ...             ...         ...        ...         ...       ...   ...    ...
# 33158  202110040812  2015110065       1171         427    897009  11.0      6
# 33156  202110040812  2018104097       1168        1044     30030   9.0      7
# 33155  202110040812  2017100368        732         431    240033   8.0      7
# 33157  202110040812  2016105133       1115        1183    180800  10.0      8
# 33148  202110040812  2017102850        666        1049    523005   1.0      8
#
# ...

# %%
results_23_p
# Out:
#             race_id    horse_id  jockey_id  trainer_id  owner_id  rank  frame  \
# 28101  202001010101  2018102410       1176         427    165033   4.0      1
# 28099  202001010101  2018105193       5339         386    486800   2.0      2
# 28100  202001010101  2018104800       1032        1082    415800   3.0      3
# 28102  202001010101  2018100828       1116        1069    750030   5.0      4
# 28103  202001010101  2018106434       1109        1010    312803   6.0      5
# ...             ...         ...        ...         ...       ...   ...    ...
# 33731  202010020812  2017106438       1152        1098    478030   2.0      6
# 33738  202010020812  2017103149       1168        1039    933006   9.0      7
# 33744  202010020812  2017105123       1166        1087    506800  15.0      7
# 33741  202010020812  2016110126       1115        1022    138007  12.0      8
# 33742  202010020812  2015102639       1124         429     95700  13.0      8
#
# ...

# %%
results_22_to_23 = pd.concat([results_22_p, results_23_p])

# %%
results_22_to_23.to_csv(os.path.join(local_paths.COMPLETED_DIR, 'results_20_to_21.csv'), sep="\t")

# %%
results_22_path = os.path.join(local_paths.COMPLETED_DIR, "results_20_to_21.csv")
results_22_p = pd.read_csv(results_22_path, index_col=0, encoding='utf8', sep='\t')
results_23_path = os.path.join(local_paths.COMPLETED_DIR, "results_22_to_23.csv")
results_23_p = pd.read_csv(results_23_path, index_col=0, encoding='utf8', sep='\t')

# %%
results_22_to_23 = pd.concat([results_22_p, results_23_p])
results_22_to_23.to_csv(os.path.join(local_paths.COMPLETED_DIR, 'results_20_to_23.csv'), sep="\t")

# %%
results_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47876 entries, 28101 to 33742
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   race_id      47876 non-null  int64
#  1   horse_id     47876 non-null  int64
#  2   jockey_id    47876 non-null  int64
#  3   trainer_id   47876 non-null  int64
#  4   owner_id     47876 non-null  int64
#  5   rank         47876 non-null  float64
#  6   frame        47876 non-null  int32
#  7   number       47876 non-null  int32
#  8   sex          47876 non-null  int64
#  9   age          47876 non-null  int32
#  10  impost       47876 non-null  float64
#  11  win_odds     47876 non-null  float64
#  12  popularity   47876 non-null  int32
#  13  weight       47876 non-null  int32
#  14  weight_diff  47876 non-null  int32
# dtypes: float64(3), int32(6), int64(6)
# memory usage: 4.7 MB

# %%
results_p.duplicated(subset=["race_id", "horse_id"]).sum()
# Out:
# np.int64(0)

# %%
results_p.isnull().sum()
# Out:
# race_id        0
# horse_id       0
# jockey_id      0
# trainer_id     0
# owner_id       0
# rank           0
# frame          0
# number         0
# sex            0
# age            0
# impost         0
# win_odds       0
# popularity     0
# weight         0
# weight_diff    0
# dtype: int64

# %% [markdown]
# ## 馬の過去成績データの前処理

# %%
# %autoreload

# %%
y=2020

# %%
horse_results_p = preprocessing.process_horse_results(save_file_name=f"horse_results_{y}.csv")
# Out:
# c:\Users\SV8\m\p\keiba\modules\preprocessing.py:101: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(os.path.join(input_dir, save_file_name), sep="\t")

# %%
horse_results_path = os.path.join(local_paths.PREPROCESSED_DIR, f"horse_results_{y}.csv")
horse_results_p = pd.read_csv(horse_results_path, index_col=0, encoding='utf8', sep='\t')

# %%
horse_results_p
# Out:
#           horse_id        date  weather  race_class  n_horses  rank  \
# 1       2017101464  2021-08-15      1.0         5.0       9.0   7.0
# 3       2017101464  2021-07-18      0.0         NaN       7.0   1.0
# 4       2017101464  2021-07-11      1.0         5.0      10.0   9.0
# 5       2017101464  2021-01-17      0.0         2.0      14.0  11.0
# 6       2017101464  2020-11-08      0.0         2.0      13.0  10.0
# ...            ...         ...      ...         ...       ...   ...
# 329467  2016104128  2020-01-02      0.0         3.0      10.0   2.0
# 329468  2016104128  2019-12-18      1.0         3.0      10.0   2.0
# 329469  2016104128  2019-08-29      0.0         5.0      10.0   9.0
# 329470  2016104128  2019-07-13      1.0         1.0      16.0  15.0
# 329471  2016104128  2019-05-11      0.0         1.0      16.0  15.0
#
#         race_type  course_len  ground_state  rank_diff  3_furlongs   time  \
# 1               1        1500           2.0        1.2        39.0   97.2
# ...

# %%
horse_results_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250224 entries, 0 to 253545
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   horse_id      250224 non-null  int64
#  1   date          250224 non-null  object
#  2   weather       249997 non-null  float64
#  3   race_class    160220 non-null  float64
#  4   n_horses      250224 non-null  float64
#  5   rank          250224 non-null  float64
#  6   race_type     250224 non-null  int64
#  7   course_len    250224 non-null  int64
#  8   ground_state  250223 non-null  float64
#  9   rank_diff     249956 non-null  float64
#  10  3_furlongs    249939 non-null  float64
#  11  time          250047 non-null  float64
#  12  prize         250224 non-null  float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 26.7+ MB

# %% [markdown]
# ## レース情報データの前処理

# %%
# %autoreload

# %%
y = 2020

# %%
race_info = preprocessing.process_race_info(save_file_name=f"race_info_{y}.csv")

# %%
race_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3456 entries, 0 to 3455
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   race_id       3456 non-null   int64
#  1   date          3456 non-null   datetime64[ns]
#  2   race_type     3456 non-null   int64
#  3   around        3309 non-null   float64
#  4   course_len    3432 non-null   float64
#  5   weather       3433 non-null   float64
#  6   ground_state  3433 non-null   float64
#  7   race_class    3393 non-null   float64
#  8   place         3348 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2)
# memory usage: 243.1 KB

# %%
race_info.value_counts()
# Out:
# race_id       date        race_type  around  course_len  weather  ground_state  race_class  place
# 202001010101  2020-07-25  0          0.0     1800.0      1.0      0.0           1.0         0.0      1
# 202008010708  2020-01-19  1          0.0     1800.0      1.0      0.0           2.0         7.0      1
# 202008010710  2020-01-19  0          0.0     2000.0      1.0      0.0           5.0         7.0      1
# 202008010711  2020-01-19  0          0.0     2400.0      1.0      0.0           8.0         7.0      1
# 202008010712  2020-01-19  1          0.0     1200.0      1.0      0.0           3.0         7.0      1
#                                                                                                     ..
# 202005030610  2020-06-21  0          1.0     1400.0      1.0      1.0           4.0         4.0      1
# 202005030611  2020-06-21  1          1.0     1600.0      1.0      1.0           8.0         4.0      1
# ...

# %%
race_info
# Out:
#            race_id       date  race_type  around  course_len  weather  \
# 0     202006010101 2020-01-05          1     0.0      1200.0      0.0
# 1     202006010102 2020-01-05          1     0.0      1800.0      0.0
# 2     202006010103 2020-01-05          1     0.0      1200.0      0.0
# 3     202006010104 2020-01-05          1     0.0      1800.0      0.0
# 4     202006010105 2020-01-05          0     0.0      2000.0      0.0
# ...            ...        ...        ...     ...         ...      ...
# 3451  202009060808 2020-12-27          1     0.0      1800.0      0.0
# 3452  202009060809 2020-12-27          0     0.0      1600.0      0.0
# 3453  202009060810 2020-12-27          1     0.0      1800.0      0.0
# 3454  202009060811 2020-12-27          1     0.0      1400.0      0.0
# 3455  202009060812 2020-12-27          0     0.0      1400.0      0.0
#
#       ground_state  race_class  place
# 0              0.0         1.0    5.0
# 1              0.0         1.0    5.0
# ...

# %%
race_info_path = os.path.join(local_paths.PREPROCESSED_DIR, f"race_info_{y}.csv")
race_info_p = pd.read_csv(race_info_path, index_col=0, encoding='utf8', sep='\t')

# %%
race_info_p
# Out:
#            race_id        date  race_type  around  course_len  weather  \
# 0     202006010101  2020-01-05          1     0.0      1200.0      0.0
# 1     202006010102  2020-01-05          1     0.0      1800.0      0.0
# 2     202006010103  2020-01-05          1     0.0      1200.0      0.0
# 3     202006010104  2020-01-05          1     0.0      1800.0      0.0
# 4     202006010105  2020-01-05          0     0.0      2000.0      0.0
# ...            ...         ...        ...     ...         ...      ...
# 3451  202009060808  2020-12-27          1     0.0      1800.0      0.0
# 3452  202009060809  2020-12-27          0     0.0      1600.0      0.0
# 3453  202009060810  2020-12-27          1     0.0      1800.0      0.0
# 3454  202009060811  2020-12-27          1     0.0      1400.0      0.0
# 3455  202009060812  2020-12-27          0     0.0      1400.0      0.0
#
#       ground_state  race_class  place
# 0              0.0         1.0    5.0
# ...

# %%
race_info_p['course_len'].isnull().sum()
# Out:
# np.int64(28)

# %%
# %autoreload

# %%
returns_22 = preprocessing.process_returns(save_file_name='returns_2022.csv')

# %%
returns_23 = preprocessing.process_returns(save_file_name='returns_2023.csv')

# %%
returns_23
# Out:
#              単勝_rank 単勝_returns      複勝_rank        複勝_returns 枠連_rank  \
# race_id
# 202306010101    [14]      [180]   [14, 5, 1]   [110, 150, 480]  [3, 7]
# 202306010102     [8]     [1380]   [8, 7, 13]   [460, 440, 400]  [4, 4]
# 202306010103    [16]     [1590]   [16, 9, 2]  [540, 1000, 440]  [5, 8]
# 202306010104     [7]     [1590]   [7, 13, 1]   [330, 290, 150]  [4, 7]
# 202306010105     [1]      [690]   [1, 3, 16]   [180, 150, 170]  [1, 2]
# ...              ...        ...          ...               ...     ...
# 202309050908     [8]      [270]   [8, 14, 3]   [160, 170, 650]  [5, 8]
# 202309050909    [16]      [350]  [16, 9, 14]  [200, 1410, 460]  [5, 8]
# 202309050910    [11]     [1710]   [11, 6, 9]   [390, 200, 190]  [6, 8]
# 202309050911    [15]      [610]  [15, 10, 5]   [170, 110, 170]  [6, 8]
# 202309050912     [2]     [3250]   [2, 12, 5]   [520, 220, 140]  [1, 6]
#
#              枠連_returns   馬連_rank 馬連_returns                ワイド_rank  \
# race_id
# ...

# %%
df = pd.read_csv(os.path.join(local_paths.PREPROCESSED_DIR, 'returns_2022.csv'), sep="\t")

# %%
df
# Out:
#            race_id 単勝_rank 単勝_returns      複勝_rank        複勝_returns 枠連_rank  \
# 0     202206010101    [15]      [680]  [15, 10, 4]  [210, 1600, 170]  [5, 8]
# 1     202206010102     [1]     [1510]   [1, 8, 10]   [280, 110, 220]  [1, 4]
# 2     202206010103     [5]      [430]   [5, 7, 11]  [130, 2620, 110]  [3, 4]
# 3     202206010104     [5]      [630]   [5, 6, 10]   [190, 120, 450]  [5, 6]
# 4     202206010105     [8]      [190]    [8, 6, 9]   [110, 110, 140]  [6, 8]
# ...            ...     ...        ...          ...               ...     ...
# 3451  202209060908    [10]      [290]   [10, 6, 1]   [140, 130, 270]  [6, 8]
# 3452  202209060909    [16]      [410]  [16, 14, 7]   [180, 320, 310]  [7, 8]
# 3453  202209060910    [13]     [2820]   [13, 8, 2]   [930, 290, 400]  [5, 8]
# 3454  202209060911     [4]      [520]  [4, 10, 12]   [170, 330, 210]  [4, 7]
# 3455  202209060912     [7]      [480]    [7, 2, 4]   [180, 160, 220]  [1, 4]
#
# ...

# %%
df.iloc[1,1]
# Out:
# '[1, 1510]'

# %% [markdown]
# ## 馬の血統データ

# %%
# %autoreload

# %%
y = 2020

# %%
peds_22 = pd.read_csv(os.path.join(local_paths.RAW_DIR, f'peds_{y}.csv'), index_col=0 ,sep="\t")
peds_22
# Out:
#                    0             1
# horse_id
# 2017101464   ヘニーヒューズ          ヘネシー
# 2017101464   ヘニーヒューズ  Meadow Flyer
# 2017101464     ハロータマ       ゼンノエルシド
# 2017101464     ハロータマ     タマビッグエックス
# 2017103291    トーセンラー     ディープインパクト
# ...              ...           ...
# 2015103736  ヒシヴァリアント         アニマII
# 2016104128   グランプリボス     サクラバクシンオー
# 2016104128   グランプリボス       ロージーミスト
# 2016104128    マンイーター       タイキシャトル
# 2016104128    マンイーター        フォーチュン
#
# [46808 rows x 2 columns]

# %%
peds_22_p = preprocessing.process_peds(save_file_name=f'peds_{y}.csv')
# Out:
# 100%|██████████| 11702/11702 [00:00<00:00, 13865.84it/s]

# %%
peds_22_p

# %%
peds_df = pd.read_csv(os.path.join(local_paths.PREPROCESSED_DIR, f'peds_{y}.csv') ,sep="\t")
peds_df
# Out:
#          horse_id       parent_0            parent_1         parent_2  \
# 0      2009100502      メイショウボーラー                  ズリ          タイキシャトル
# 1      2009102606       ロージズインメイ              キミホウセキ    Devil His Due
# 2      2009103405         スズカマンボ             ルンルンスズカ        サンデーサイレンス
# 3      2010100035        キングヘイロー              ダイタクピア        ダンシングブレーヴ
# 4      2010100690      ストーミングホーム             ビールジャント    Machiavellian
# ...           ...            ...                 ...              ...
# 11697  2018110135  Midnight Lute            My Kitty       Real Quiet
# 11698  2018110136       Mshawish  Little Miss Muffet   Medaglia d'Oro
# 11699  2018110138      Mineshaft       Mare and Cher        A.P. Indy
# 11700  2018110139        Tapizar            Allencat            Tapit
# 11701  2018110145   Quality Road       Miss Singhsix  Elusive Quality
#
#                   parent_3       parent_4       parent_5
# 0                   ナイスレイズ        Kris S.       Amizette
# ...

# %%
peds_1 = pd.read_csv(os.path.join(local_paths.PREPROCESSED_DIR, 'peds_2022.csv') ,sep="\t")
peds_0 = pd.read_csv(os.path.join(local_paths.PREPROCESSED_DIR, 'peds_2023.csv') ,sep="\t")

# %%
peds = pd.concat([peds_0, peds_1])
peds = peds.drop_duplicates()
peds
# Out:
#          horse_id         parent_0          parent_1      parent_2  \
# 0      2011106610         タニノギムレット              クロネコ     ブライアンズタイム
# 1      2012100683          マツリダゴッホ           コスモクラッベ     サンデーサイレンス
# 2      2012103532          ステイゴールド            ウェンブリー     サンデーサイレンス
# 3      2012104463        メイショウサムソン             ランペイア        オペラハウス
# 4      2012104504        ゴールドアリュール              アガルタ     サンデーサイレンス
# ...           ...              ...               ...           ...
# 11469  2020109164         ホッコータルマエ           サトノコンドル      キングカメハメハ
# 11500  2020110064       Union Rags            Trensa   Dixie Union
# 11527  2020110110          Frosted        Tim's Girl         Tapit
# 11529  2020110112    City of Light            Banree  Quality Road
# 11541  2020110135  More Than Ready  Nutcracker Suite       サザンヘイロー
#
#              parent_3          parent_4   parent_5
# 0            タニノクリスタル         ダンスインザダーク   フサイチグレース
# 1             ペイパーレイン            マイネルラヴ     ビンゴハナコ
# ...

# %%
peds.to_csv(os.path.join(local_paths.COMPLETED_DIR, 'peds_22_to_23.csv') ,sep="\t")

# %%
peds_c_1 = pd.read_csv(os.path.join(local_paths.COMPLETED_DIR, 'peds_20_to_21.csv') ,index_col=0 ,sep="\t")
peds_c_0 = pd.read_csv(os.path.join(local_paths.COMPLETED_DIR, 'peds_22_to_23.csv') ,index_col=0 ,sep="\t")

# %%
peds_c_1
# Out:
#          horse_id      parent_0         parent_1          parent_2  \
# 0      2009100502     メイショウボーラー               ズリ           タイキシャトル
# 1      2009102606      ロージズインメイ           キミホウセキ     Devil His Due
# 2      2009103405        スズカマンボ          ルンルンスズカ         サンデーサイレンス
# 3      2010100035       キングヘイロー           ダイタクピア         ダンシングブレーヴ
# 4      2010100690     ストーミングホーム          ビールジャント     Machiavellian
# ...           ...           ...              ...               ...
# 11562  2019110118      Arrogate  Amen Hallelujah  Unbridled's Song
# 11563  2019110119      Arrogate       Flatter Up  Unbridled's Song
# 11564  2019110121  Quality Road      Gone Callin   Elusive Quality
# 11565  2019110122         Klimt      Brave Cause      Quality Road
# 11566  2019110123       Connect       Wild Hoots            Curlin
#
#               parent_3          parent_4        parent_5
# 0               ナイスレイズ           Kris S.        Amizette
# ...

# %%
peds_c_0
# Out:
#          horse_id         parent_0          parent_1      parent_2  \
# 0      2011106610         タニノギムレット              クロネコ     ブライアンズタイム
# 1      2012100683          マツリダゴッホ           コスモクラッベ     サンデーサイレンス
# 2      2012103532          ステイゴールド            ウェンブリー     サンデーサイレンス
# 3      2012104463        メイショウサムソン             ランペイア        オペラハウス
# 4      2012104504        ゴールドアリュール              アガルタ     サンデーサイレンス
# ...           ...              ...               ...           ...
# 11469  2020109164         ホッコータルマエ           サトノコンドル      キングカメハメハ
# 11500  2020110064       Union Rags            Trensa   Dixie Union
# 11527  2020110110          Frosted        Tim's Girl         Tapit
# 11529  2020110112    City of Light            Banree  Quality Road
# 11541  2020110135  More Than Ready  Nutcracker Suite       サザンヘイロー
#
#              parent_3          parent_4   parent_5
# 0            タニノクリスタル         ダンスインザダーク   フサイチグレース
# 1             ペイパーレイン            マイネルラヴ     ビンゴハナコ
# ...

# %%
peds_c = pd.concat([peds_c_0, peds_c_1])
peds_c = peds_c.drop_duplicates()
peds_c
# Out:
#          horse_id   parent_0         parent_1   parent_2    parent_3  \
# 0      2011106610   タニノギムレット             クロネコ  ブライアンズタイム    タニノクリスタル
# 1      2012100683    マツリダゴッホ          コスモクラッベ  サンデーサイレンス     ペイパーレイン
# 2      2012103532    ステイゴールド           ウェンブリー  サンデーサイレンス   ゴールデンサッシュ
# 3      2012104463  メイショウサムソン            ランペイア     オペラハウス    マイヴィヴィアン
# 4      2012104504  ゴールドアリュール             アガルタ  サンデーサイレンス        ニキーヤ
# ...           ...        ...              ...        ...         ...
# 11471  2019109134    ロードバリオス       アヴェニューズレディ  ブライアンズタイム    レディブラッサム
# 11473  2019109136     ケイムホーム          イマヒトタビノ  Gone West  Nice Assay
# 11487  2019109164    ダノンシャーク         テイエムビックイ  ディープインパクト      カーラパワー
# 11488  2019109165  テイエムオペラオー         テイエムヨカオゴ     オペラハウス      ワンスウエド
# 11502  2019110027    Teofilo  Heat Of The Day    Galileo  Speirbhean
#
#               parent_4         parent_5
# 0            ダンスインザダーク         フサイチグレース
# 1               マイネルラヴ           ビンゴハナコ
# ...

# %%
peds_c.to_csv(os.path.join(local_paths.COMPLETED_DIR, 'peds_20_to_23.csv') ,sep="\t")

# %% [markdown]
# ## 騎手データの加工

# %%
# %autoreload

# %%
y = 2023

# %%
jockeys_df = pd.read_csv(os.path.join(local_paths.RAW_DIR, f'jockeys_{y}.csv') ,sep="\t")
jockeys_df['勝率'].isnull().sum()
# Out:
# 0

# %%
jockeys = preprocessing.process_jockeys(save_file_name=f'jockeys_{y}.csv')

# %%
jockeys_df = pd.read_csv(os.path.join(local_paths.PREPROCESSED_DIR, f'jockeys_{y}.csv') , index_col=0, sep="\t", dtype={'jockey_id': str})
jockeys_df
# Out:
#       annual jockey_id  jockey_rank  jockey_n_top_1  jockey_n_top_2  \
# 1       2024     00666            7              78              56
# 2       2023     00666           10              74              61
# 3       2022     00666           11              73              81
# 4       2021     00666           11              75              62
# 5       2020     00666            5             115             103
# ...      ...       ...          ...             ...             ...
# 2865    2023     05629          152               0               0
# 2866    2022     05629          147               0               0
# 2868    2023     05580          152               0               0
# 2869    2019     05580          149               0               1
# 2870    2018     05580          148               0               0
#
#       jockey_n_top_3  jockey_n_4th_or_below  jockey_stakes_participation  \
# 1                 43                    282                           46
# ...

# %%
jockeys = pd.read_csv(os.path.join(local_paths.PREPROCESSED_DIR, f'jockeys_{y}.csv') , index_col=0, sep="\t", dtype={'jockey_id': str})
jockeys
# Out:
#       annual jockey_id  jockey_rank  jockey_n_top_1  jockey_n_top_2  \
# 1       2024     01075           23              35              54
# 2       2023     01075           14              57              58
# 3       2022     01075           13              72              66
# 4       2021     01075           15              66              59
# 5       2020     01075           10              74              87
# ...      ...       ...          ...             ...             ...
# 2765    2021     05608          135               0               0
# 2767    2021     05611          135               0               0
# 2769    2022     05607          147               0               0
# 2770    2021     05607          135               0               0
# 2772    2021     05605          135               0               0
#
#       jockey_n_top_3  jockey_n_4th_or_below  jockey_stakes_participation  \
# 1                 39                    305                           26
# ...

# %%
path_22 = os.path.join(local_paths.PREPROCESSED_DIR, "jockeys_2022.csv")
jockeys_22 = pd.read_csv(path_22, encoding='utf8', sep='\t', index_col=0, dtype={'jockey_id': str})
path_23 = os.path.join(local_paths.PREPROCESSED_DIR, "jockeys_2023.csv")
jockeys_23 = pd.read_csv(path_23, encoding='utf8', sep='\t', index_col=0, dtype={'jockey_id': str})

# %%
jockeys_22_to_23 =pd.concat([jockeys_22, jockeys_23]).drop_duplicates()
jockeys_22_to_23
# Out:
#       annual jockey_id  jockey_rank  jockey_n_top_1  jockey_n_top_2  \
# 1       2024     01192           72              11              13
# 2       2023     01192           52              23              17
# 3       2022     01192           37              34              27
# 4       2021     01192           81               9               7
# 6       2024     01179           14              51              61
# ...      ...       ...          ...             ...             ...
# 2860    2023     05648          152               0               0
# 2862    2023     05617          152               0               0
# 2868    2023     05580          152               0               0
# 2869    2019     05580          149               0               1
# 2870    2018     05580          148               0               0
#
#       jockey_n_top_3  jockey_n_4th_or_below  jockey_stakes_participation  \
# 1                 18                    239                            4
# ...

# %%
jockeys_22_to_23.to_csv(os.path.join(local_paths.COMPLETED_DIR, 'jockeys_22_to_23.csv'), sep="\t")

# %%
path_22 = os.path.join(local_paths.COMPLETED_DIR, "jockeys_20_to_21.csv")
jockeys_1 = pd.read_csv(path_22, encoding='utf8', sep='\t', index_col=0, dtype={'jockey_id': str})
path_23 = os.path.join(local_paths.COMPLETED_DIR, "jockeys_22_to_23.csv")
jockeys_0 = pd.read_csv(path_23, encoding='utf8', sep='\t', index_col=0, dtype={'jockey_id': str})

# %%
jockeys_df =pd.concat([jockeys_1, jockeys_0]).drop_duplicates()
jockeys_df
# Out:
#       annual jockey_id  jockey_rank  jockey_n_top_1  jockey_n_top_2  \
# 1       2024     01075           23              35              54
# 2       2023     01075           14              57              58
# 3       2022     01075           13              72              66
# 4       2021     01075           15              66              59
# 5       2020     01075           10              74              87
# ...      ...       ...          ...             ...             ...
# 2860    2023     05648          152               0               0
# 2862    2023     05617          152               0               0
# 2868    2023     05580          152               0               0
# 2869    2019     05580          149               0               1
# 2870    2018     05580          148               0               0
#
#       jockey_n_top_3  jockey_n_4th_or_below  jockey_stakes_participation  \
# 1                 39                    305                           26
# ...

# %%
jockeys_df.to_csv(os.path.join(local_paths.COMPLETED_DIR, 'jockeys_20_to_23.csv'), sep="\t")
